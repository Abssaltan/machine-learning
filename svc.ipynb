# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\ankit kumar jha\Downloads\diabetes.csv")

# %%
print(df.shape)
df.head()
# Out:
# (768, 9)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
x=df.drop('Outcome', axis=1)
y=df['Outcome']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
from sklearn.svm import SVC
svm = SVC(kernel="rbf", probability=True)
svm.fit(X_train, y_train)
# Out:
# SVC(probability=True)

# %%
y_pred=svm.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
score=accuracy_score(y_pred,y_test)
print(score)
print(classification_report(y_pred,y_test))
print(confusion_matrix(y_pred,y_test))
# Out:
# 0.7662337662337663
#               precision    recall  f1-score   support
#
#            0       0.88      0.78      0.83       111
#            1       0.56      0.72      0.63        43
#
#     accuracy                           0.77       154
#    macro avg       0.72      0.75      0.73       154
# weighted avg       0.79      0.77      0.77       154
#
# [[87 24]
#  [12 31]]

# %%
from sklearn.model_selection import GridSearchCV

c_values=[0.1, 1, 10]
kernel=['linear', 'rbf', 'poly']
gamma=['scale', 'auto']
params=dict(C=c_values,kernel=kernel,gamma=gamma)

# %%
from sklearn.model_selection import StratifiedKFold
cv=StratifiedKFold()

# %%
from sklearn.model_selection import GridSearchCV

grid=GridSearchCV(estimator=svm,param_grid=params,scoring='accuracy',cv=cv,n_jobs=-1)

# %%
grid

# %%
grid.fit(X_train,y_train)

# %%
grid.best_score_
